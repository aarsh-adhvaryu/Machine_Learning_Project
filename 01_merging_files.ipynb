# %%
# Cell 1 - Imports and configuration
import os
import glob
import time
import pandas as pd
import numpy as np

# Paths (edit if needed)
RAW_PATH = r"D:\ML_Project\data\raw"
PROCESSED_PATH = r"D:\ML_Project\data\processed"

os.makedirs(RAW_PATH, exist_ok=True)
os.makedirs(PROCESSED_PATH, exist_ok=True)

# Files we will create
MASTER_PREFIX = "MASTER_"
UNIQUE_DEMO_FILE = os.path.join(PROCESSED_PATH, "UNIQUE_DEMO.csv")
FINAL_MASTER_FILE = os.path.join(PROCESSED_PATH, "FINAL_MASTER_DATASET.csv")

# Quarterly file pattern config
YEARS = range(2015, 2026)  # inclusive start, exclusive end in loops below
QUARTERS = [
    "Q1",
    "Q2",
    "Q3",
    "Q4",
]  # note: your raw files may use different quarter naming - adjust if needed

print("RAW_PATH:", RAW_PATH)
print("PROCESSED_PATH:", PROCESSED_PATH)
# Out:
# RAW_PATH: D:\ML_Project\data\raw
# PROCESSED_PATH: D:\ML_Project\data\processed

# %%
# Cell 2 - Build MASTER_* files from quarterly .txt files (robust concat)
# This step is idempotent: it writes MASTER_<TYPE>.csv if it finds quarterly files.
# If your MASTER_*.csv already exist and you don't want to rebuild, skip this cell.

FILE_TYPES = {
    "DEMO": [
        "primaryid",
        "caseid",
        "caseversion",
        "i_f_code",
        "event_dt",
        "mfr_dt",
        "init_fda_dt",
        "fda_dt",
        "rept_cod",
        "auth_num",
        "mfr_num",
        "mfr_sndr",
        "lit_ref",
        "age",
        "age_cod",
        "age_grp",
        "sex",
        "e_sub",
        "wt",
        "wt_cod",
        "rept_dt",
        "to_mfr",
        "occp_cod",
        "reporter_country",
        "occr_country",
    ],
    "DRUG": [
        "primaryid",
        "caseid",
        "drug_seq",
        "role_cod",
        "drugname",
        "prod_ai",
        "val_vbm",
        "route",
        "dose_vbm",
        "cum_dose_chr",
        "cum_dose_unit",
        "dechal",
        "rechal",
        "lot_num",
        "exp_dt",
        "nda_num",
        "dose_amt",
        "dose_unit",
        "dose_form",
        "dose_freq",
    ],
    "INDI": ["primaryid", "caseid", "indi_drug_seq", "indi_pt"],
    "OUTC": ["primaryid", "caseid", "outc_cod"],
    "REAC": ["primaryid", "caseid", "pt"],
    "THER": [
        "primaryid",
        "caseid",
        "dsg_drug_seq",
        "start_dt",
        "end_dt",
        "dur",
        "dur_cod",
    ],
}


def process_quarterly_to_master(ftype, master_cols):
    pattern_glob = os.path.join(RAW_PATH, f"{ftype}*.txt")
    quarterly_files = []
    # collect files by expected naming convention (FTYYQ)
    for year in YEARS:
        for q in QUARTERS:
            # e.g., DEMO15Q1 or DEMO15Q1.txt — try variants
            two = str(year)[-2:]
            candidates = [
                os.path.join(RAW_PATH, f"{ftype.upper()}{two}{q}.txt"),
                os.path.join(RAW_PATH, f"{ftype.upper()}{two}{q}.TXT"),
                os.path.join(
                    RAW_PATH, f"{ftype.upper()}{two}{q}.*"
                ),  # catch other extensions if present
            ]
            for c in candidates:
                found = glob.glob(c)
                if found:
                    quarterly_files.extend(found)

    if not quarterly_files:
        print(
            f"No quarterly files found for {ftype}. Skipping creation of MASTER_{ftype}.csv"
        )
        return None

    out_file = os.path.join(RAW_PATH, f"MASTER_{ftype}.csv")
    print(f"Found {len(quarterly_files)} files for {ftype}. Building {out_file} ...")

    # We'll stream-append to avoid memory pressure
    n_written = 0
    for i, fpath in enumerate(sorted(set(quarterly_files))):
        try:
            df_q = pd.read_csv(
                fpath, sep="$", dtype=str, on_bad_lines="skip", engine="python"
            )
            df_q.columns = df_q.columns.str.lower()
            # keep only columns that match master cols (case-insensitive)
            cols_lower = [c.lower() for c in master_cols]
            keep = [c for c in df_q.columns if c in cols_lower]
            df_q = df_q[keep].copy()

            # ensure all master cols exist (create missing)
            for mc in master_cols:
                if mc not in df_q.columns:
                    df_q[mc] = pd.NA

            # reorder and rename to canonical master names
            df_q = df_q[[c for c in master_cols]]
            # write/append
            if n_written == 0:
                df_q.to_csv(out_file, index=False, mode="w")
            else:
                df_q.to_csv(out_file, index=False, mode="a", header=False)
            n_written += len(df_q)
            print(f"  {os.path.basename(fpath)} -> {len(df_q)} rows")
        except Exception as e:
            print(f"  Error reading {fpath}: {e}")

    print(f"MASTER_{ftype}.csv saved: {out_file} ({n_written} rows)")
    return out_file


# Build each MASTER_* file (only if files exist)
for ft, cols in FILE_TYPES.items():
    try:
        process_quarterly_to_master(ft, cols)
    except Exception as e:
        print(f"Error processing {ft}: {e}")

print("MASTER file build step completed.")
# Out:
# Found 168 files for DEMO. Building D:\ML_Project\data\raw\MASTER_DEMO.csv ...
#   DEMO15Q1.TXT -> 317071 rows
#   DEMO15Q1.txt -> 317071 rows
#   DEMO15Q2.TXT -> 289270 rows
#   DEMO15Q2.txt -> 289270 rows
#   DEMO15Q3.TXT -> 398860 rows
#   DEMO15Q3.txt -> 398860 rows
#   DEMO15Q4.TXT -> 314704 rows
#   DEMO15Q4.txt -> 314704 rows
#   DEMO16Q1.TXT -> 365682 rows
#   DEMO16Q1.txt -> 365682 rows
#   DEMO16Q2.TXT -> 316056 rows
#   DEMO16Q2.txt -> 316056 rows
#   DEMO16Q3.TXT -> 313613 rows
#   DEMO16Q3.txt -> 313613 rows
#   DEMO16Q4.TXT -> 309534 rows
#   DEMO16Q4.txt -> 309534 rows
#   DEMO17Q1.TXT -> 352913 rows
#   DEMO17Q1.txt -> 352913 rows
#   DEMO17Q2.TXT -> 337398 rows
#   DEMO17Q2.txt -> 337398 rows
#   DEMO17Q3.TXT -> 351388 rows
#   DEMO17Q3.txt -> 351388 rows
#   DEMO17Q4.TXT -> 327848 rows
#   DEMO17Q4.txt -> 327848 rows
#   DEMO18Q1.TXT -> 412702 rows
#   DEMO18Q1.txt -> 412702 rows
#   DEMO18Q2.TXT -> 457169 rows
#   DEMO18Q2.txt -> 457169 rows
#   DEMO18Q3.TXT -> 420915 rows
#   DEMO18Q3.txt -> 420915 rows
#   DEMO18Q4.TXT -> 394066 rows
#   DEMO18Q4.txt -> 394066 rows
#   DEMO19Q1.TXT -> 413734 rows
#   Error reading D:\ML_Project\data\raw\DEMO19Q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 3373: invalid start byte
#   DEMO19Q1.txt -> 413734 rows
#   DEMO19Q3.TXT -> 452873 rows
#   DEMO19Q3.txt -> 452873 rows
#   DEMO19Q4.TXT -> 419581 rows
#   DEMO19Q4.txt -> 419581 rows
#   DEMO20Q1.TXT -> 460327 rows
#   DEMO20Q1.txt -> 460327 rows
#   DEMO20Q2.TXT -> 429227 rows
#   DEMO20Q2.txt -> 429227 rows
#   DEMO20Q3.TXT -> 431667 rows
#   DEMO20Q3.txt -> 431667 rows
#   DEMO20Q4.TXT -> 436148 rows
#   DEMO20Q4.txt -> 436148 rows
#   DEMO21Q1.TXT -> 463741 rows
#   DEMO21Q1.txt -> 463741 rows
#   DEMO21Q2.TXT -> 479945 rows
#   DEMO21Q2.txt -> 479945 rows
#   DEMO21Q3.TXT -> 504160 rows
#   DEMO21Q3.txt -> 504160 rows
#   DEMO21Q4.TXT -> 412542 rows
#   Error reading D:\ML_Project\data\raw\DEMO21Q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   DEMO21Q4.txt -> 412542 rows
#   DEMO22Q1.TXT -> 461623 rows
#   Error reading D:\ML_Project\data\raw\DEMO22Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DEMO22Q1.txt -> 461623 rows
#   DEMO22Q2.TXT -> 435618 rows
#   Error reading D:\ML_Project\data\raw\DEMO22Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DEMO22Q2.txt -> 435618 rows
#   DEMO22Q3.TXT -> 446511 rows
#   Error reading D:\ML_Project\data\raw\DEMO22Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DEMO22Q3.txt -> 446511 rows
#   DEMO22Q4.TXT -> 483643 rows
#   Error reading D:\ML_Project\data\raw\DEMO22Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DEMO22Q4.txt -> 483643 rows
#   DEMO23Q1.TXT -> 432144 rows
#   Error reading D:\ML_Project\data\raw\DEMO23Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DEMO23Q1.txt -> 432144 rows
#   DEMO23Q2.TXT -> 418592 rows
#   Error reading D:\ML_Project\data\raw\DEMO23Q2.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   DEMO23Q2.txt -> 418592 rows
#   DEMO23Q3.TXT -> 407522 rows
#   Error reading D:\ML_Project\data\raw\DEMO23Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DEMO23Q3.txt -> 407522 rows
#   DEMO23Q4.TXT -> 415379 rows
#   Error reading D:\ML_Project\data\raw\DEMO23Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DEMO23Q4.txt -> 415379 rows
#   DEMO24Q1.TXT -> 406184 rows
#   Error reading D:\ML_Project\data\raw\DEMO24Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DEMO24Q1.txt -> 406184 rows
#   DEMO24Q2.TXT -> 397119 rows
#   Error reading D:\ML_Project\data\raw\DEMO24Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DEMO24Q2.txt -> 397119 rows
#   DEMO24Q3.TXT -> 405513 rows
#   Error reading D:\ML_Project\data\raw\DEMO24Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DEMO24Q3.txt -> 405513 rows
#   DEMO24Q4.TXT -> 410849 rows
#   Error reading D:\ML_Project\data\raw\DEMO24Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DEMO24Q4.txt -> 410849 rows
#   DEMO25Q1.TXT -> 400514 rows
#   Error reading D:\ML_Project\data\raw\DEMO25Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DEMO25Q1.txt -> 400514 rows
#   DEMO25Q2.TXT -> 393130 rows
#   Error reading D:\ML_Project\data\raw\DEMO25Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DEMO25Q2.txt -> 393130 rows
#   DEMO25Q3.TXT -> 438512 rows
#   Error reading D:\ML_Project\data\raw\DEMO25Q3.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   DEMO25Q3.txt -> 438512 rows
#   Error reading D:\ML_Project\data\raw\demo15q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 6046: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo15q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 5920: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo15q3.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\demo15q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 4058: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo16q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 5914: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo16q2.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\demo16q3.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\demo16q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 5576: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo17q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\demo17q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 2953: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo17q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 3178: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo17q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\demo18q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\demo18q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 3172: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo18q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 7394: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo18q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 3389: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo19q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 3383: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo19q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 3374: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo20q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 4290: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo20q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 706: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo20q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 4207: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo20q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\demo21q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\demo21q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 789: invalid start byte
#   Error reading D:\ML_Project\data\raw\demo21q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 4214: invalid start byte
# MASTER_DEMO.csv saved: D:\ML_Project\data\raw\MASTER_DEMO.csv (33871974 rows)
# Found 168 files for DRUG. Building D:\ML_Project\data\raw\MASTER_DRUG.csv ...
#   DRUG15Q1.TXT -> 1082833 rows
#   DRUG15Q1.txt -> 1082833 rows
#   DRUG15Q2.TXT -> 967120 rows
#   DRUG15Q2.txt -> 967120 rows
#   DRUG15Q3.TXT -> 1294625 rows
#   DRUG15Q3.txt -> 1294625 rows
#   DRUG15Q4.TXT -> 1064332 rows
#   DRUG15Q4.txt -> 1064332 rows
#   DRUG16Q1.TXT -> 1202390 rows
#   DRUG16Q1.txt -> 1202390 rows
#   DRUG16Q2.TXT -> 1144148 rows
#   DRUG16Q2.txt -> 1144148 rows
#   DRUG16Q3.TXT -> 1257054 rows
#   DRUG16Q3.txt -> 1257054 rows
#   DRUG16Q4.TXT -> 1147547 rows
#   DRUG16Q4.txt -> 1147547 rows
#   DRUG17Q1.TXT -> 1234393 rows
#   DRUG17Q1.txt -> 1234393 rows
#   DRUG17Q2.TXT -> 1188078 rows
#   DRUG17Q2.txt -> 1188078 rows
#   DRUG17Q3.TXT -> 1220118 rows
#   DRUG17Q3.txt -> 1220118 rows
#   DRUG17Q4.TXT -> 1213842 rows
#   DRUG17Q4.txt -> 1213842 rows
#   DRUG18Q1.TXT -> 1686461 rows
#   DRUG18Q1.txt -> 1686461 rows
#   DRUG18Q2.TXT -> 1987872 rows
#   DRUG18Q2.txt -> 1987872 rows
#   DRUG18Q3.TXT -> 1651966 rows
#   DRUG18Q3.txt -> 1651966 rows
#   DRUG18Q4.TXT -> 1546835 rows
#   DRUG18Q4.txt -> 1546835 rows
#   DRUG19Q1.TXT -> 1648987 rows
#   Error reading D:\ML_Project\data\raw\DRUG19Q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 4413: invalid start byte
#   DRUG19Q1.txt -> 1648987 rows
#   Error reading D:\ML_Project\data\raw\DRUG19Q3.TXT: 'utf-8' codec can't decode byte 0xad in position 3221: invalid start byte
#   Error reading D:\ML_Project\data\raw\DRUG19Q3.txt: 'utf-8' codec can't decode byte 0xad in position 3221: invalid start byte
#   DRUG19Q4.TXT -> 1714177 rows
#   DRUG19Q4.txt -> 1714177 rows
#   DRUG20Q1.TXT -> 1943532 rows
#   DRUG20Q1.txt -> 1943532 rows
#   DRUG20Q2.TXT -> 1825414 rows
#   DRUG20Q2.txt -> 1825414 rows
#   DRUG20Q3.TXT -> 1895153 rows
#   DRUG20Q3.txt -> 1895153 rows
#   DRUG20Q4.TXT -> 1918927 rows
#   DRUG20Q4.txt -> 1918927 rows
#   DRUG21Q1.TXT -> 2208416 rows
#   DRUG21Q1.txt -> 2208416 rows
#   DRUG21Q2.TXT -> 2291903 rows
#   DRUG21Q2.txt -> 2291903 rows
#   DRUG21Q3.TXT -> 2260570 rows
#   DRUG21Q3.txt -> 2260570 rows
#   DRUG21Q4.TXT -> 1778675 rows
#   Error reading D:\ML_Project\data\raw\DRUG21Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DRUG21Q4.txt -> 1778675 rows
#   DRUG22Q1.TXT -> 1994171 rows
#   Error reading D:\ML_Project\data\raw\DRUG22Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DRUG22Q1.txt -> 1994171 rows
#   DRUG22Q2.TXT -> 1828103 rows
#   Error reading D:\ML_Project\data\raw\DRUG22Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DRUG22Q2.txt -> 1828103 rows
#   DRUG22Q3.TXT -> 1835461 rows
#   Error reading D:\ML_Project\data\raw\DRUG22Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DRUG22Q3.txt -> 1835461 rows
#   DRUG22Q4.TXT -> 2006967 rows
#   Error reading D:\ML_Project\data\raw\DRUG22Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DRUG22Q4.txt -> 2006967 rows
#   DRUG23Q1.TXT -> 1899503 rows
#   Error reading D:\ML_Project\data\raw\DRUG23Q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   DRUG23Q1.txt -> 1899503 rows
#   DRUG23Q2.TXT -> 1885096 rows
#   Error reading D:\ML_Project\data\raw\DRUG23Q2.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   DRUG23Q2.txt -> 1885096 rows
#   DRUG23Q3.TXT -> 1768391 rows
#   Error reading D:\ML_Project\data\raw\DRUG23Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DRUG23Q3.txt -> 1768391 rows
#   DRUG23Q4.TXT -> 1920732 rows
#   Error reading D:\ML_Project\data\raw\DRUG23Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DRUG23Q4.txt -> 1920732 rows
#   DRUG24Q1.TXT -> 1909327 rows
#   Error reading D:\ML_Project\data\raw\DRUG24Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DRUG24Q1.txt -> 1909327 rows
#   DRUG24Q2.TXT -> 1888937 rows
#   Error reading D:\ML_Project\data\raw\DRUG24Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DRUG24Q2.txt -> 1888937 rows
#   DRUG24Q3.TXT -> 1907293 rows
#   Error reading D:\ML_Project\data\raw\DRUG24Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DRUG24Q3.txt -> 1907293 rows
#   DRUG24Q4.TXT -> 2030938 rows
#   Error reading D:\ML_Project\data\raw\DRUG24Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DRUG24Q4.txt -> 2030938 rows
#   DRUG25Q1.TXT -> 2008162 rows
#   Error reading D:\ML_Project\data\raw\DRUG25Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DRUG25Q1.txt -> 2008162 rows
#   DRUG25Q2.TXT -> 1829056 rows
#   Error reading D:\ML_Project\data\raw\DRUG25Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   DRUG25Q2.txt -> 1829056 rows
#   DRUG25Q3.TXT -> 2148451 rows
#   Error reading D:\ML_Project\data\raw\DRUG25Q3.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   DRUG25Q3.txt -> 2148451 rows
#   Error reading D:\ML_Project\data\raw\drug15q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\drug15q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 5142: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug15q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 6815: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug15q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 2464: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug16q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 3115: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug16q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 3055: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug16q3.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\drug16q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\drug17q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\drug17q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 4100: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug17q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 292: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug17q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\drug18q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 3914: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug18q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 34: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug18q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 4448: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug18q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 5312: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug19q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 5278: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug19q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 4999: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug20q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 4744: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug20q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 3034: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug20q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 3372: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug20q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\drug21q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\drug21q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 4748: invalid start byte
#   Error reading D:\ML_Project\data\raw\drug21q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 4444: invalid start byte
# MASTER_DRUG.csv saved: D:\ML_Project\data\raw\MASTER_DRUG.csv (138471912 rows)
# Found 167 files for INDI. Building D:\ML_Project\data\raw\MASTER_INDI.csv ...
#   INDI15Q1.TXT -> 748742 rows
#   INDI15Q1.txt -> 748742 rows
#   INDI15Q2.TXT -> 659529 rows
#   INDI15Q2.txt -> 659529 rows
#   INDI15Q3.TXT -> 811279 rows
#   INDI15Q3.txt -> 811279 rows
#   INDI15Q4.TXT -> 718340 rows
#   INDI15Q4.txt -> 718340 rows
#   INDI16Q1.TXT -> 878267 rows
#   INDI16Q1.txt -> 878267 rows
#   INDI16Q2.TXT -> 798489 rows
#   INDI16Q2.txt -> 798489 rows
#   INDI16Q3.TXT -> 816898 rows
#   INDI16Q3.txt -> 816898 rows
#   INDI16Q4.TXT -> 755832 rows
#   INDI16Q4.txt -> 755832 rows
#   INDI17Q1.TXT -> 859833 rows
#   INDI17Q1.txt -> 859833 rows
#   INDI17Q2.TXT -> 816254 rows
#   INDI17Q2.txt -> 816254 rows
#   INDI17Q3.TXT -> 844974 rows
#   INDI17Q3.txt -> 844974 rows
#   INDI17Q4.TXT -> 863690 rows
#   INDI17Q4.txt -> 863690 rows
#   INDI18Q1.TXT -> 1253118 rows
#   INDI18Q1.txt -> 1253118 rows
#   INDI18Q2.TXT -> 1428287 rows
#   INDI18Q2.txt -> 1428287 rows
#   INDI18Q3.TXT -> 1134135 rows
#   INDI18Q3.txt -> 1134135 rows
#   INDI18Q4.TXT -> 1064664 rows
#   INDI18Q4.txt -> 1064664 rows
#   INDI19Q1.TXT -> 1106754 rows
#   Error reading D:\ML_Project\data\raw\INDI19Q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 7132: invalid start byte
#   INDI19Q1.txt -> 1106754 rows
#   INDI19Q3.TXT -> 1353011 rows
#   INDI19Q3.txt -> 1353011 rows
#   INDI19Q4.TXT -> 1146938 rows
#   INDI19Q4.txt -> 1146938 rows
#   INDI20Q1.TXT -> 1348658 rows
#   INDI20Q1.txt -> 1348658 rows
#   INDI20Q2.TXT -> 1294010 rows
#   INDI20Q2.txt -> 1294010 rows
#   INDI20Q3.TXT -> 1276348 rows
#   INDI20Q3.txt -> 1276348 rows
#   INDI20Q4.TXT -> 1297446 rows
#   INDI20Q4.txt -> 1297446 rows
#   INDI21Q1.TXT -> 1603039 rows
#   INDI21Q1.txt -> 1603039 rows
#   INDI21Q2.TXT -> 1659378 rows
#   INDI21Q2.txt -> 1659378 rows
#   INDI21Q3.TXT -> 1588679 rows
#   INDI21Q3.txt -> 1588679 rows
#   INDI21Q4.TXT -> 1234766 rows
#   Error reading D:\ML_Project\data\raw\INDI21Q4.pdf: 'utf-8' codec can't decode byte 0xb5 in position 11: invalid start byte
#   INDI21Q4.txt -> 1234766 rows
#   INDI22Q1.TXT -> 1347146 rows
#   Error reading D:\ML_Project\data\raw\INDI22Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   INDI22Q1.txt -> 1347146 rows
#   INDI22Q2.TXT -> 1150299 rows
#   Error reading D:\ML_Project\data\raw\INDI22Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   INDI22Q2.txt -> 1150299 rows
#   INDI22Q3.TXT -> 1159203 rows
#   Error reading D:\ML_Project\data\raw\INDI22Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   INDI22Q3.txt -> 1159203 rows
#   INDI22Q4.TXT -> 1321489 rows
#   Error reading D:\ML_Project\data\raw\INDI22Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   INDI22Q4.txt -> 1321489 rows
#   INDI23Q1.TXT -> 1176237 rows
#   Error reading D:\ML_Project\data\raw\INDI23Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   INDI23Q1.txt -> 1176237 rows
#   INDI23Q2.TXT -> 1165782 rows
#   Error reading D:\ML_Project\data\raw\INDI23Q2.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   INDI23Q2.txt -> 1165782 rows
#   INDI23Q3.TXT -> 1063761 rows
#   Error reading D:\ML_Project\data\raw\INDI23Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   INDI23Q3.txt -> 1063761 rows
#   INDI23Q4.TXT -> 1115961 rows
#   Error reading D:\ML_Project\data\raw\INDI23Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   INDI23Q4.txt -> 1115961 rows
#   INDI24Q1.TXT -> 1186115 rows
#   Error reading D:\ML_Project\data\raw\INDI24Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   INDI24Q1.txt -> 1186115 rows
#   INDI24Q2.TXT -> 1187626 rows
#   Error reading D:\ML_Project\data\raw\INDI24Q2.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   INDI24Q2.txt -> 1187626 rows
#   INDI24Q3.TXT -> 1177133 rows
#   Error reading D:\ML_Project\data\raw\INDI24Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   INDI24Q3.txt -> 1177133 rows
#   INDI24Q4.TXT -> 1219759 rows
#   Error reading D:\ML_Project\data\raw\INDI24Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   INDI24Q4.txt -> 1219759 rows
#   INDI25Q1.TXT -> 1205861 rows
#   Error reading D:\ML_Project\data\raw\INDI25Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   INDI25Q1.txt -> 1205861 rows
#   INDI25Q2.TXT -> 1136665 rows
#   Error reading D:\ML_Project\data\raw\INDI25Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   INDI25Q2.txt -> 1136665 rows
#   INDI25Q3.TXT -> 1310274 rows
#   Error reading D:\ML_Project\data\raw\INDI25Q3.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   INDI25Q3.txt -> 1310274 rows
#   Error reading D:\ML_Project\data\raw\indi15q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 2311: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi15q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 2299: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi15q3.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\indi15q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 7227: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi16q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 3904: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi16q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 2383: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi16q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 7531: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi16q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 7528: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi17q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\indi17q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 7124: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi17q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 6994: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi17q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\indi18q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 7033: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi18q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 7167: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi18q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 7153: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi19q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 7210: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi19q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 7066: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi20q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 3624: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi20q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 7188: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi20q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 7110: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi20q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\indi21q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\indi21q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 7051: invalid start byte
#   Error reading D:\ML_Project\data\raw\indi21q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 510: invalid start byte
# MASTER_INDI.csv saved: D:\ML_Project\data\raw\MASTER_INDI.csv (94569338 rows)
# Found 166 files for OUTC. Building D:\ML_Project\data\raw\MASTER_OUTC.csv ...
#   OUTC15Q1.TXT -> 238008 rows
#   OUTC15Q1.txt -> 238008 rows
#   OUTC15Q2.TXT -> 200423 rows
#   OUTC15Q2.txt -> 200423 rows
#   OUTC15Q3.TXT -> 213108 rows
#   OUTC15Q3.txt -> 213108 rows
#   OUTC15Q4.TXT -> 205080 rows
#   OUTC15Q4.txt -> 205080 rows
#   OUTC16Q1.TXT -> 210280 rows
#   OUTC16Q1.txt -> 210280 rows
#   OUTC16Q2.TXT -> 218745 rows
#   OUTC16Q2.txt -> 218745 rows
#   OUTC16Q3.TXT -> 221346 rows
#   OUTC16Q3.txt -> 221346 rows
#   OUTC16Q4.TXT -> 220468 rows
#   OUTC16Q4.txt -> 220468 rows
#   OUTC17Q1.TXT -> 242274 rows
#   OUTC17Q1.txt -> 242274 rows
#   OUTC17Q2.TXT -> 232053 rows
#   OUTC17Q2.txt -> 232053 rows
#   OUTC17Q3.TXT -> 233715 rows
#   OUTC17Q3.txt -> 233715 rows
#   OUTC17Q4.TXT -> 243176 rows
#   OUTC17Q4.txt -> 243176 rows
#   OUTC18Q1.TXT -> 298710 rows
#   OUTC18Q1.txt -> 298710 rows
#   OUTC18Q2.TXT -> 331947 rows
#   OUTC18Q2.txt -> 331947 rows
#   OUTC18Q3.TXT -> 295817 rows
#   OUTC18Q3.txt -> 295817 rows
#   OUTC18Q4.TXT -> 299135 rows
#   OUTC18Q4.txt -> 299135 rows
#   OUTC19Q1.TXT -> 310662 rows
#   Error reading D:\ML_Project\data\raw\OUTC19Q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 1461: invalid start byte
#   OUTC19Q1.txt -> 310662 rows
#   OUTC19Q3.TXT -> 323787 rows
#   OUTC19Q3.txt -> 323787 rows
#   OUTC19Q4.TXT -> 321603 rows
#   OUTC19Q4.txt -> 321603 rows
#   OUTC20Q1.TXT -> 335470 rows
#   OUTC20Q1.txt -> 335470 rows
#   OUTC20Q2.TXT -> 307509 rows
#   OUTC20Q2.txt -> 307509 rows
#   OUTC20Q3.TXT -> 358815 rows
#   OUTC20Q3.txt -> 358815 rows
#   OUTC20Q4.TXT -> 365575 rows
#   OUTC20Q4.txt -> 365575 rows
#   OUTC21Q1.TXT -> 371698 rows
#   OUTC21Q1.txt -> 371698 rows
#   OUTC21Q2.TXT -> 383928 rows
#   OUTC21Q2.txt -> 383928 rows
#   OUTC21Q3.TXT -> 420729 rows
#   OUTC21Q3.txt -> 420729 rows
#   OUTC21Q4.TXT -> 337168 rows
#   Error reading D:\ML_Project\data\raw\OUTC21Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC21Q4.txt -> 337168 rows
#   OUTC22Q1.TXT -> 375497 rows
#   Error reading D:\ML_Project\data\raw\OUTC22Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC22Q1.txt -> 375497 rows
#   OUTC22Q2.TXT -> 325309 rows
#   Error reading D:\ML_Project\data\raw\OUTC22Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC22Q2.txt -> 325309 rows
#   OUTC22Q3.TXT -> 345763 rows
#   Error reading D:\ML_Project\data\raw\OUTC22Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC22Q3.txt -> 345763 rows
#   OUTC22Q4.TXT -> 334611 rows
#   Error reading D:\ML_Project\data\raw\OUTC22Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC22Q4.txt -> 334611 rows
#   OUTC23Q1.TXT -> 309217 rows
#   Error reading D:\ML_Project\data\raw\OUTC23Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC23Q1.txt -> 309217 rows
#   OUTC23Q2.TXT -> 303513 rows
#   Error reading D:\ML_Project\data\raw\OUTC23Q2.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   OUTC23Q2.txt -> 303513 rows
#   OUTC23Q3.TXT -> 307396 rows
#   Error reading D:\ML_Project\data\raw\OUTC23Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC23Q3.txt -> 307396 rows
#   OUTC23Q4.TXT -> 327797 rows
#   Error reading D:\ML_Project\data\raw\OUTC23Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC23Q4.txt -> 327797 rows
#   OUTC24Q1.TXT -> 295044 rows
#   Error reading D:\ML_Project\data\raw\OUTC24Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC24Q1.txt -> 295044 rows
#   OUTC24Q2.TXT -> 291572 rows
#   Error reading D:\ML_Project\data\raw\OUTC24Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC24Q2.txt -> 291572 rows
#   OUTC24Q3.TXT -> 288275 rows
#   Error reading D:\ML_Project\data\raw\OUTC24Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC24Q3.txt -> 288275 rows
#   OUTC24Q4.TXT -> 308960 rows
#   Error reading D:\ML_Project\data\raw\OUTC24Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC24Q4.txt -> 308960 rows
#   OUTC25Q1.TXT -> 304027 rows
#   Error reading D:\ML_Project\data\raw\OUTC25Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC25Q1.txt -> 304027 rows
#   OUTC25Q2.TXT -> 295583 rows
#   Error reading D:\ML_Project\data\raw\OUTC25Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   OUTC25Q2.txt -> 295583 rows
#   OUTC25Q3.TXT -> 343251 rows
#   Error reading D:\ML_Project\data\raw\OUTC25Q3.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   OUTC25Q3.txt -> 343251 rows
#   Error reading D:\ML_Project\data\raw\outc15q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 529: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc15q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 3778: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc15q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 3792: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc15q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 447: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc16q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 3867: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc16q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 6790: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc16q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 1878: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc17q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\outc17q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 1474: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc17q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 1380: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc17q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\outc18q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 2458: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc18q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 1390: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc18q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 1694: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc18q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 1507: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc19q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 1562: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc19q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 1581: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc20q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 1542: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc20q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 1488: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc20q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 1559: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc20q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\outc21q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 1592: invalid start byte
#   Error reading D:\ML_Project\data\raw\outc21q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 1544: invalid start byte
# MASTER_OUTC.csv saved: D:\ML_Project\data\raw\MASTER_OUTC.csv (24994088 rows)
# Found 168 files for REAC. Building D:\ML_Project\data\raw\MASTER_REAC.csv ...
#   REAC15Q1.TXT -> 872848 rows
#   REAC15Q1.txt -> 872848 rows
#   REAC15Q2.TXT -> 845134 rows
#   REAC15Q2.txt -> 845134 rows
#   REAC15Q3.TXT -> 1133196 rows
#   REAC15Q3.txt -> 1133196 rows
#   REAC15Q4.TXT -> 968664 rows
#   REAC15Q4.txt -> 968664 rows
#   REAC16Q1.TXT -> 1013744 rows
#   REAC16Q1.txt -> 1013744 rows
#   REAC16Q2.TXT -> 914638 rows
#   REAC16Q2.txt -> 914638 rows
#   REAC16Q3.TXT -> 936744 rows
#   REAC16Q3.txt -> 936744 rows
#   REAC16Q4.TXT -> 916308 rows
#   REAC16Q4.txt -> 916308 rows
#   REAC17Q1.TXT -> 1041509 rows
#   REAC17Q1.txt -> 1041509 rows
#   REAC17Q2.TXT -> 987728 rows
#   REAC17Q2.txt -> 987728 rows
#   REAC17Q3.TXT -> 1025153 rows
#   REAC17Q3.txt -> 1025153 rows
#   REAC17Q4.TXT -> 961640 rows
#   REAC17Q4.txt -> 961640 rows
#   REAC18Q1.TXT -> 1206259 rows
#   REAC18Q1.txt -> 1206259 rows
#   REAC18Q2.TXT -> 1392439 rows
#   REAC18Q2.txt -> 1392439 rows
#   REAC18Q3.TXT -> 1329530 rows
#   REAC18Q3.txt -> 1329530 rows
#   REAC18Q4.TXT -> 1250978 rows
#   REAC18Q4.txt -> 1250978 rows
#   REAC19Q1.TXT -> 1303532 rows
#   Error reading D:\ML_Project\data\raw\REAC19Q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 6824: invalid start byte
#   REAC19Q1.txt -> 1303532 rows
#   REAC19Q3.TXT -> 1504790 rows
#   REAC19Q3.txt -> 1504790 rows
#   REAC19Q4.TXT -> 1359922 rows
#   REAC19Q4.txt -> 1359922 rows
#   REAC20Q1.TXT -> 1517264 rows
#   REAC20Q1.txt -> 1517264 rows
#   REAC20Q2.TXT -> 1437285 rows
#   REAC20Q2.txt -> 1437285 rows
#   REAC20Q3.TXT -> 1454044 rows
#   REAC20Q3.txt -> 1454044 rows
#   REAC20Q4.TXT -> 1522657 rows
#   REAC20Q4.txt -> 1522657 rows
#   REAC21Q1.TXT -> 1505167 rows
#   REAC21Q1.txt -> 1505167 rows
#   REAC21Q2.TXT -> 1526544 rows
#   REAC21Q2.txt -> 1526544 rows
#   REAC21Q3.TXT -> 1544374 rows
#   REAC21Q3.txt -> 1544374 rows
#   REAC21Q4.TXT -> 1355734 rows
#   Error reading D:\ML_Project\data\raw\REAC21Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC21Q4.txt -> 1355734 rows
#   REAC22Q1.TXT -> 1543059 rows
#   Error reading D:\ML_Project\data\raw\REAC22Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC22Q1.txt -> 1543059 rows
#   REAC22Q2.TXT -> 1464627 rows
#   Error reading D:\ML_Project\data\raw\REAC22Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC22Q2.txt -> 1464627 rows
#   REAC22Q3.TXT -> 1449509 rows
#   Error reading D:\ML_Project\data\raw\REAC22Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC22Q3.txt -> 1449509 rows
#   REAC22Q4.TXT -> 1617584 rows
#   Error reading D:\ML_Project\data\raw\REAC22Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC22Q4.txt -> 1617584 rows
#   REAC23Q1.TXT -> 1491473 rows
#   Error reading D:\ML_Project\data\raw\REAC23Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC23Q1.txt -> 1491473 rows
#   REAC23Q2.TXT -> 1478973 rows
#   Error reading D:\ML_Project\data\raw\REAC23Q2.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   REAC23Q2.txt -> 1478973 rows
#   REAC23Q3.TXT -> 1373338 rows
#   Error reading D:\ML_Project\data\raw\REAC23Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC23Q3.txt -> 1373338 rows
#   REAC23Q4.TXT -> 1500033 rows
#   Error reading D:\ML_Project\data\raw\REAC23Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC23Q4.txt -> 1500033 rows
#   REAC24Q1.TXT -> 1445416 rows
#   Error reading D:\ML_Project\data\raw\REAC24Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC24Q1.txt -> 1445416 rows
#   REAC24Q2.TXT -> 1445044 rows
#   Error reading D:\ML_Project\data\raw\REAC24Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC24Q2.txt -> 1445044 rows
#   REAC24Q3.TXT -> 1431718 rows
#   Error reading D:\ML_Project\data\raw\REAC24Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC24Q3.txt -> 1431718 rows
#   REAC24Q4.TXT -> 1472750 rows
#   Error reading D:\ML_Project\data\raw\REAC24Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC24Q4.txt -> 1472750 rows
#   REAC25Q1.TXT -> 1432926 rows
#   Error reading D:\ML_Project\data\raw\REAC25Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC25Q1.txt -> 1432926 rows
#   REAC25Q2.TXT -> 1340666 rows
#   Error reading D:\ML_Project\data\raw\REAC25Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   REAC25Q2.txt -> 1340666 rows
#   REAC25Q3.TXT -> 1535133 rows
#   Error reading D:\ML_Project\data\raw\REAC25Q3.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   REAC25Q3.txt -> 1535133 rows
#   Error reading D:\ML_Project\data\raw\reac15q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 2107: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac15q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 2116: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac15q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 2074: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac15q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 6934: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac16q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 2114: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac16q2.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\reac16q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 7149: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac16q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 80: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac17q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\reac17q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 7995: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac17q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 6139: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac17q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\reac18q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 6653: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac18q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 7885: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac18q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 6794: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac18q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 4189: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac19q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 6815: invalid start byte
#   reac19q4.pdf -> 577 rows
#   Error reading D:\ML_Project\data\raw\reac20q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 3113: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac20q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 7964: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac20q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 6635: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac20q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\reac21q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\reac21q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 7870: invalid start byte
#   Error reading D:\ML_Project\data\raw\reac21q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 6718: invalid start byte
# MASTER_REAC.csv saved: D:\ML_Project\data\raw\MASTER_REAC.csv (109700725 rows)
# Found 168 files for THER. Building D:\ML_Project\data\raw\MASTER_THER.csv ...
#   THER15Q1.TXT -> 374935 rows
#   THER15Q1.txt -> 374935 rows
#   THER15Q2.TXT -> 373850 rows
#   THER15Q2.txt -> 373850 rows
#   THER15Q3.TXT -> 494584 rows
#   THER15Q3.txt -> 494584 rows
#   THER15Q4.TXT -> 401725 rows
#   THER15Q4.txt -> 401725 rows
#   THER16Q1.TXT -> 458946 rows
#   THER16Q1.txt -> 458946 rows
#   THER16Q2.TXT -> 464701 rows
#   THER16Q2.txt -> 464701 rows
#   THER16Q3.TXT -> 483082 rows
#   THER16Q3.txt -> 483082 rows
#   THER16Q4.TXT -> 433545 rows
#   THER16Q4.txt -> 433545 rows
#   THER17Q1.TXT -> 455411 rows
#   THER17Q1.txt -> 455411 rows
#   THER17Q2.TXT -> 454078 rows
#   THER17Q2.txt -> 454078 rows
#   THER17Q3.TXT -> 443213 rows
#   THER17Q3.txt -> 443213 rows
#   THER17Q4.TXT -> 442433 rows
#   THER17Q4.txt -> 442433 rows
#   THER18Q1.TXT -> 551394 rows
#   THER18Q1.txt -> 551394 rows
#   THER18Q2.TXT -> 688053 rows
#   THER18Q2.txt -> 688053 rows
#   THER18Q3.TXT -> 663319 rows
#   THER18Q3.txt -> 663319 rows
#   THER18Q4.TXT -> 620308 rows
#   THER18Q4.txt -> 620308 rows
#   THER19Q1.TXT -> 627355 rows
#   Error reading D:\ML_Project\data\raw\THER19Q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 1190: invalid start byte
#   THER19Q1.txt -> 627355 rows
#   THER19Q3.TXT -> 776039 rows
#   THER19Q3.txt -> 776039 rows
#   THER19Q4.TXT -> 643525 rows
#   THER19Q4.txt -> 643525 rows
#   Error reading D:\ML_Project\data\raw\THER20Q1.PDF: 'utf-8' codec can't decode byte 0x89 in position 1361: invalid start byte
#   THER20Q1.TXT -> 728199 rows
#   THER20Q1.txt -> 728199 rows
#   THER20Q2.TXT -> 636959 rows
#   THER20Q2.txt -> 636959 rows
#   THER20Q3.TXT -> 646462 rows
#   THER20Q3.txt -> 646462 rows
#   THER20Q4.TXT -> 681411 rows
#   THER20Q4.txt -> 681411 rows
#   THER21Q1.TXT -> 786472 rows
#   THER21Q1.txt -> 786472 rows
#   THER21Q2.TXT -> 789968 rows
#   THER21Q2.txt -> 789968 rows
#   THER21Q3.TXT -> 848661 rows
#   THER21Q3.txt -> 848661 rows
#   THER21Q4.TXT -> 671045 rows
#   Error reading D:\ML_Project\data\raw\THER21Q4.pdf: 'utf-8' codec can't decode byte 0xb5 in position 11: invalid start byte
#   THER21Q4.txt -> 671045 rows
#   THER22Q1.TXT -> 748899 rows
#   Error reading D:\ML_Project\data\raw\THER22Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   THER22Q1.txt -> 748899 rows
#   THER22Q2.TXT -> 690828 rows
#   Error reading D:\ML_Project\data\raw\THER22Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   THER22Q2.txt -> 690828 rows
#   THER22Q3.TXT -> 717902 rows
#   Error reading D:\ML_Project\data\raw\THER22Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   THER22Q3.txt -> 717902 rows
#   THER22Q4.TXT -> 726767 rows
#   Error reading D:\ML_Project\data\raw\THER22Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   THER22Q4.txt -> 726767 rows
#   THER23Q1.TXT -> 683408 rows
#   Error reading D:\ML_Project\data\raw\THER23Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   THER23Q1.txt -> 683408 rows
#   THER23Q2.TXT -> 678128 rows
#   Error reading D:\ML_Project\data\raw\THER23Q2.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   THER23Q2.txt -> 678128 rows
#   THER23Q3.TXT -> 593027 rows
#   Error reading D:\ML_Project\data\raw\THER23Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   THER23Q3.txt -> 593027 rows
#   THER23Q4.TXT -> 633087 rows
#   Error reading D:\ML_Project\data\raw\THER23Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   THER23Q4.txt -> 633087 rows
#   THER24Q1.TXT -> 594449 rows
#   Error reading D:\ML_Project\data\raw\THER24Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   THER24Q1.txt -> 594449 rows
#   THER24Q2.TXT -> 539334 rows
#   Error reading D:\ML_Project\data\raw\THER24Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   THER24Q2.txt -> 539334 rows
#   THER24Q3.TXT -> 532854 rows
#   Error reading D:\ML_Project\data\raw\THER24Q3.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   THER24Q3.txt -> 532854 rows
#   THER24Q4.TXT -> 561889 rows
#   Error reading D:\ML_Project\data\raw\THER24Q4.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   THER24Q4.txt -> 561889 rows
#   THER25Q1.TXT -> 520395 rows
#   Error reading D:\ML_Project\data\raw\THER25Q1.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   THER25Q1.txt -> 520395 rows
#   THER25Q2.TXT -> 512759 rows
#   Error reading D:\ML_Project\data\raw\THER25Q2.pdf: 'utf-8' codec can't decode byte 0xc8 in position 10: invalid continuation byte
#   THER25Q2.txt -> 512759 rows
#   THER25Q3.TXT -> 514480 rows
#   Error reading D:\ML_Project\data\raw\THER25Q3.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   THER25Q3.txt -> 514480 rows
#   Error reading D:\ML_Project\data\raw\ther15q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 3468: invalid start byte
#   Error reading D:\ML_Project\data\raw\ther15q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 1837: invalid start byte
#   Error reading D:\ML_Project\data\raw\ther15q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 3475: invalid start byte
#   Error reading D:\ML_Project\data\raw\ther15q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 133: invalid start byte
#   Error reading D:\ML_Project\data\raw\ther16q1.pdf: 'utf-8' codec can't decode byte 0x89 in position 149: invalid start byte
#   Error reading D:\ML_Project\data\raw\ther16q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 3502: invalid start byte
#   Error reading D:\ML_Project\data\raw\ther16q3.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\ther16q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\ther17q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\ther17q2.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\ther17q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 1119: invalid start byte
#   Error reading D:\ML_Project\data\raw\ther17q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\ther18q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\ther18q2.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\ther18q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 1278: invalid start byte
#   Error reading D:\ML_Project\data\raw\ther18q4.pdf: 'utf-8' codec can't decode byte 0x89 in position 1226: invalid start byte
#   Error reading D:\ML_Project\data\raw\ther19q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 1193: invalid start byte
#   Error reading D:\ML_Project\data\raw\ther19q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\ther20q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 1223: invalid start byte
#   Error reading D:\ML_Project\data\raw\ther20q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 1178: invalid start byte
#   Error reading D:\ML_Project\data\raw\ther20q4.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\ther21q1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
#   Error reading D:\ML_Project\data\raw\ther21q2.pdf: 'utf-8' codec can't decode byte 0x89 in position 1199: invalid start byte
#   Error reading D:\ML_Project\data\raw\ther21q3.pdf: 'utf-8' codec can't decode byte 0x89 in position 1230: invalid start byte
# MASTER_THER.csv saved: D:\ML_Project\data\raw\MASTER_THER.csv (49775758 rows)
# MASTER file build step completed.

# %%
# Cell 3 - Deduplicate MASTER_DEMO.csv to UNIQUE_DEMO.csv (keep latest per case)
MASTER_DEMO_FILE = os.path.join(RAW_PATH, "MASTER_DEMO.csv")
if not os.path.exists(MASTER_DEMO_FILE):
    print(f"WARNING: {MASTER_DEMO_FILE} not found. Skipping deduplication step.")
else:
    print(
        "Loading MASTER_DEMO.csv for deduplication (may be large; this can take time)..."
    )
    df_demo = pd.read_csv(MASTER_DEMO_FILE, dtype=str, low_memory=False)
    # normalize date column
    if "fda_dt" in df_demo.columns:
        df_demo["fda_dt_parsed"] = pd.to_datetime(
            df_demo["fda_dt"], format="%Y%m%d", errors="coerce"
        )
    else:
        df_demo["fda_dt_parsed"] = pd.NaT

    # convert keys to numeric safe
    df_demo["primaryid"] = pd.to_numeric(
        df_demo.get("primaryid", pd.NA), errors="coerce"
    )
    df_demo["caseid"] = pd.to_numeric(df_demo.get("caseid", pd.NA), errors="coerce")

    # drop rows missing primaryid
    before = len(df_demo)
    df_demo = df_demo.dropna(subset=["primaryid"])
    print(f"Dropped {before - len(df_demo)} rows with missing primaryid")

    # sort so the first per caseid is the latest (by fda_dt then primaryid)
    if "caseid" in df_demo.columns:
        df_demo.sort_values(
            by=["caseid", "fda_dt_parsed", "primaryid"],
            ascending=[True, False, False],
            inplace=True,
        )
        df_unique = df_demo.drop_duplicates(subset=["caseid"], keep="first")
    else:
        # if no caseid present, fallback to primaryid uniqueness
        df_demo.sort_values(by=["primaryid"], ascending=True, inplace=True)
        df_unique = df_demo.drop_duplicates(subset=["primaryid"], keep="first")

    # Write unique demo
    df_unique.to_csv(UNIQUE_DEMO_FILE, index=False)
    print(f"Saved UNIQUE_DEMO.csv -> {UNIQUE_DEMO_FILE} ({len(df_unique):,} rows)")
# Out:
# Loading MASTER_DEMO.csv for deduplication (may be large; this can take time)...
# Dropped 0 rows with missing primaryid
# Saved UNIQUE_DEMO.csv -> D:\ML_Project\data\processed\UNIQUE_DEMO.csv (2,818,644 rows)

# %%
# Cell 4 - Define aggregation functions (OUTC, REAC, DRUG, INDI, THER)
MASTER_OUTC_FILE = os.path.join(RAW_PATH, "MASTER_OUTC.csv")
MASTER_REAC_FILE = os.path.join(RAW_PATH, "MASTER_REAC.csv")
MASTER_DRUG_FILE = os.path.join(RAW_PATH, "MASTER_DRUG.csv")
MASTER_INDI_FILE = os.path.join(RAW_PATH, "MASTER_INDI.csv")
MASTER_THER_FILE = os.path.join(RAW_PATH, "MASTER_THER.csv")

SEVERE_OUTCOMES = {"DE", "LT", "HO", "DS"}
INEFFICACY_TERMS = [
    "DRUG INEFFECTIVE",
    "LACK OF EFFECT",
    "THERAPEUTIC RESPONSE DECREASED",
    "CONDITION WORSENED",
]


def safe_read_csv(path, usecols=None):
    if not os.path.exists(path):
        print(f"File not found: {path} (returning empty df)")
        return pd.DataFrame()
    try:
        return pd.read_csv(path, dtype=str, usecols=usecols, low_memory=False)
    except Exception as e:
        print(f"Error reading {path}: {e}")
        return pd.DataFrame()


def process_outcomes(path):
    df = safe_read_csv(path, usecols=["primaryid", "outc_cod"])
    if df.empty:
        return pd.DataFrame()
    df = df.dropna(subset=["primaryid", "outc_cod"])
    df["primaryid"] = pd.to_numeric(df["primaryid"], errors="coerce")
    df = df.dropna(subset=["primaryid"])
    df["outc_cod"] = df["outc_cod"].astype(str).str.strip().str.upper()
    df["is_severe_outcome"] = df["outc_cod"].isin(SEVERE_OUTCOMES).astype(int)
    agg = (
        df.groupby(df["primaryid"].astype("Int64"))["is_severe_outcome"]
        .max()
        .to_frame("is_severe_outcome")
    )
    return agg


def process_reactions(path):
    df = safe_read_csv(path, usecols=["primaryid", "pt"])
    if df.empty:
        return pd.DataFrame()
    df = df.dropna(subset=["primaryid", "pt"])
    df["primaryid"] = pd.to_numeric(df["primaryid"], errors="coerce")
    df = df.dropna(subset=["primaryid"])
    # uppercase and sanitize PTs
    df["pt_upper"] = df["pt"].astype(str).str.upper().str.strip()
    # aggregate: join all PTs into a single document per primaryid
    agg_pts = (
        df.groupby(df["primaryid"].astype("Int64"))["pt_upper"]
        .apply(lambda vals: " ".join(vals))
        .to_frame("all_reaction_pts")
    )
    agg_pts["reaction_count"] = df.groupby(df["primaryid"].astype("Int64")).size()

    # is_ineffective: check if any inefficacy phrase appears in the aggregated text
    def detect_ineff(x):
        x_upper = x if isinstance(x, str) else ""
        for term in INEFFICACY_TERMS:
            if term in x_upper:
                return 1
        return 0

    agg_pts["is_ineffective"] = (
        agg_pts["all_reaction_pts"].apply(detect_ineff).astype(int)
    )
    return agg_pts


def process_drugs(path):
    df = safe_read_csv(path, usecols=["primaryid"])
    if df.empty:
        return pd.DataFrame()
    df["primaryid"] = pd.to_numeric(df["primaryid"], errors="coerce")
    df = df.dropna(subset=["primaryid"])
    agg = df.groupby(df["primaryid"].astype("Int64")).size().to_frame("drug_count")
    return agg


def process_indications(path):
    df = safe_read_csv(path, usecols=["primaryid"])
    if df.empty:
        return pd.DataFrame()
    df["primaryid"] = pd.to_numeric(df["primaryid"], errors="coerce")
    df = df.dropna(subset=["primaryid"])
    agg = (
        df.groupby(df["primaryid"].astype("Int64")).size().to_frame("indication_count")
    )
    return agg


def process_therapy(path):
    df = safe_read_csv(path, usecols=["primaryid", "dur", "dur_cod"])
    if df.empty:
        return pd.DataFrame()
    df = df.dropna(subset=["primaryid", "dur", "dur_cod"])
    df["primaryid"] = pd.to_numeric(df["primaryid"], errors="coerce")
    df = df.dropna(subset=["primaryid"])
    df["dur_num"] = pd.to_numeric(df["dur"], errors="coerce")
    df = df.dropna(subset=["dur_num"])
    dur_map = {"DY": 1, "WK": 7, "MO": 30.4375, "YR": 365.25}
    df["mult"] = df["dur_cod"].map(dur_map)
    df = df.dropna(subset=["mult"])
    df["duration_in_days"] = df["dur_num"] * df["mult"]
    agg = (
        df.groupby(df["primaryid"].astype("Int64"))["duration_in_days"]
        .max()
        .to_frame("therapy_duration_days")
    )
    return agg


print("Aggregation helper functions ready.")
# Out:
# Aggregation helper functions ready.

# %%
# Cell 5 - Build FINAL_MASTER_DATASET.csv by joining UNIQUE_DEMO + aggregated dfs

# Load UNIQUE_DEMO
if not os.path.exists(UNIQUE_DEMO_FILE):
    raise FileNotFoundError(
        f"UNIQUE_DEMO.csv not found at {UNIQUE_DEMO_FILE}. Run deduplication first."
    )
df_base = pd.read_csv(UNIQUE_DEMO_FILE, dtype=str, low_memory=False)
# ensure primaryid numeric index (nullable Int64)
df_base["primaryid"] = pd.to_numeric(df_base.get("primaryid"), errors="coerce").astype(
    "Int64"
)
df_base = df_base[~df_base["primaryid"].isna()].copy()
df_base.set_index("primaryid", inplace=True)

print("Loaded UNIQUE_DEMO: rows =", len(df_base))

# produce aggregates
print("Processing relational tables...")
t0 = time.time()
df_outc = process_outcomes(MASTER_OUTC_FILE)
df_reac = process_reactions(MASTER_REAC_FILE)
df_drug = process_drugs(MASTER_DRUG_FILE)
df_indi = process_indications(MASTER_INDI_FILE)
df_ther = process_therapy(MASTER_THER_FILE)
print("Aggregation done in", round(time.time() - t0, 2), "s")


# Ensure indexes are all nullable Int64 and drop NA indexes
def normalize_index(df):
    if df is None or df.empty:
        return df
    df.index = pd.to_numeric(df.index, errors="coerce").astype("Int64")
    df = df[~df.index.isna()]
    return df


dfs_to_join = [
    normalize_index(df_outc),
    normalize_index(df_drug),
    normalize_index(df_indi),
    normalize_index(df_reac),
    normalize_index(df_ther),
]

print("Joining aggregated tables to base demo (left join)...")
df_final = df_base.join(dfs_to_join, how="left")

# Fill missing aggregated values with defaults
for col in ["drug_count", "indication_count", "reaction_count"]:
    if col in df_final.columns:
        df_final[col] = df_final[col].fillna(0).astype(int)

for col in ["is_severe_outcome", "is_ineffective"]:
    if col in df_final.columns:
        # Some operations may have produced floats/NaNs — fill then cast
        df_final[col] = df_final[col].fillna(0).astype(int)

# Ensure reaction text exists (string)
if "all_reaction_pts" not in df_final.columns:
    df_final["all_reaction_pts"] = ""
else:
    df_final["all_reaction_pts"] = df_final["all_reaction_pts"].fillna("").astype(str)

# Create is_failure target: severe outcome OR inefficacy
df_final["is_failure"] = (
    (df_final.get("is_severe_outcome", 0) == 1)
    | (df_final.get("is_ineffective", 0) == 1)
).astype(int)

# Save final to CSV (will be large)
print("Saving FINAL_MASTER_DATASET to:", FINAL_MASTER_FILE)
df_final.to_csv(
    FINAL_MASTER_FILE, index=True
)  # keep primaryid as index in file (first column)
print("Saved. Rows:", len(df_final), "Cols:", len(df_final.columns))

# Print summary counts
print("\n--- Summary: Failure / Outcome counts ---")
if all(
    c in df_final.columns for c in ["is_failure", "is_severe_outcome", "is_ineffective"]
):
    print(
        df_final[["is_failure", "is_severe_outcome", "is_ineffective"]]
        .value_counts()
        .sort_index()
    )
else:
    print(
        "Some columns missing for summary. Available columns:",
        df_final.columns.tolist(),
    )

# quick head
print("\nSample rows (index=primaryid):")
display(df_final.head(5))
# Out:
# Loaded UNIQUE_DEMO: rows = 2818644
# Processing relational tables...
# Processing D:\ML_Project\data\raw\MASTER_DRUG.csv in chunks...
# Processed 16,482,610 unique primaryid entries for drug_count
# Aggregation done in 484.37 s
# Joining aggregated tables to base demo (left join)...
# Saving FINAL_MASTER_DATASET to: D:\ML_Project\data\processed\FINAL_MASTER_DATASET.csv
# Saved. Rows: 2818644 Cols: 33
#
# --- Summary: Failure / Outcome counts ---
# is_failure  is_severe_outcome  is_ineffective
# 0           0                  0                 1817724
# 1           0                  1                  180490
#             1                  0                  799917
#                                1                   20513
# Name: count, dtype: int64
#
# Sample rows (index=primaryid):
#             caseid caseversion i_f_code  event_dt    mfr_dt init_fda_dt  \
# primaryid
# 33538582   3353858           2        F  20081126  20160225    19990716
# 33568652   3356865           2        F  20080113  20150223    19990716
# 33612122   3361212           2        F  20100329  20150223    19990716
# 34795972   3479597           2        F  20071105  20151103    19990318
# 34835022   3483502           2        F  20071206  20151023    19990318
#
#              fda_dt rept_cod auth_num mfr_num  ... occr_country fda_dt_parsed  \
# primaryid                                      ...
# 33538582   20160307      EXP      NaN  125829  ...           FR    2016-03-07
# 33568652   20160303      PER      NaN  124841  ...           FR    2016-03-03
# 33612122   20160303      PER      NaN  125149  ...           FR    2016-03-03
# 34795972   20160303      PER      NaN  122128  ...           FR    2016-03-03
# 34835022   20160303      PER      NaN  122073  ...           FR    2016-03-03
#
#           is_severe_outcome drug_count indication_count  \
# primaryid
# 33538582                  1          6                6
# 33568652                  1         10                6
# 33612122                  0          6                6
# 34795972                  0          4                4
# 34835022                  0          6                6
#
#                                   all_reaction_pts reaction_count  \
# primaryid
# 33538582     ESCHERICHIA SEPSIS ESCHERICHIA SEPSIS              2
# 33568652           CARDIAC FAILURE CARDIAC FAILURE              2
# 33612122                     LEUKOPENIA LEUKOPENIA              2
# 34795972   BONE MARROW FAILURE BONE MARROW FAILURE              2
# 34835022   BONE MARROW FAILURE BONE MARROW FAILURE              2
#
#           is_ineffective therapy_duration_days is_failure
# primaryid
# 33538582               0                   NaN          1
# 33568652               0                   NaN          1
# 33612122               0                   NaN          0
# 34795972               0                   NaN          0
# 34835022               0                   NaN          0
#
# [5 rows x 33 columns]

# %%
import pandas as pd

FINAL_MASTER = r"D:\ML_Project\data\processed\FINAL_MASTER_DATASET.csv"
df = pd.read_csv(FINAL_MASTER, usecols=["drug_count", "is_failure"], low_memory=False)

print("Rows:", len(df))
print("drug_count stats:")
print(df["drug_count"].describe())
print("\nFailures:")
print(df["is_failure"].value_counts())
# Out:
# Rows: 2818644
# drug_count stats:
# count    2.818644e+06
# mean     6.839403e+00
# std      9.454566e+00
# min      2.000000e+00
# 25%      2.000000e+00
# 50%      4.000000e+00
# 75%      8.000000e+00
# max      1.364000e+03
# Name: drug_count, dtype: float64
#
# Failures:
# is_failure
# 0    1817724
# 1    1000920
# Name: count, dtype: int64
